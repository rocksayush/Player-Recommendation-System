# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt #Data Visualization 
import seaborn as sns  #Python library for Vidualization
from sklearn.cluster import KMeans

# %%
def weightedAvg(data):
    rdata = pd.DataFrame()
    for player in data.pid:
        p= data[data['pid'] == player]
        ser = len(p)
        p = p.drop(['pid', 'Unnamed: 0', 'series_code'], axis = 1 )
        p = pd.DataFrame(p.mean(axis = 0))
        p = p.swapaxes('index', 'columns')

        p.insert(0, 'pid', player)
        p.insert(0, 'series_played', ser)
        rdata = rdata.append(p)
    return rdata

# %%
df = pd.read_csv('playerIR.csv')[:]
df = weightedAvg(df)
df.head()
# Out:
#    series_played     pid     batAGR     batRI     bowlAGR    bowlRI
# 0            118    29.0 -57.757441 -0.175182 -822.129235 -2.600603
# 0             53   986.0 -40.708540 -0.130786    0.000000  0.000000
# 0            157  1794.0  34.811971  0.100504  -13.062950 -0.038626
# 0             89  1959.0 -45.497939 -0.149818 -864.372082 -2.918027
# 0             61  2032.0 -53.818062 -0.157882 -997.022851 -3.090699

# %%
# fig = plt.gcf()
# fig.set_size_inches(50, 50)

plt.scatter(df.batRI, df.bowlRI, s = 50)
plt.xlabel('batting ranking index')
plt.ylabel('bowling ranking index')
# plt.figure(num=None, figsize=(4000, 4000))
plt.show()

# %%
kmeans = KMeans(n_clusters=5)

# %%
kmeans.fit(df[['batRI', 'bowlRI']])
yk = kmeans.predict(df[['batRI', 'bowlRI']])

# %%
# fig = plt.gcf()
# fig.set_size_inches(18, 18)



# for st in plt.style.available:
#     

plt.style.use('ggplot')
# print(st)
plt.scatter(df.batRI, df.bowlRI, c = yk, s=50 ,alpha = .75)
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c = 'black', s=100, alpha=.75);

# plt.xscale('linear')
# plt.yscale('linear')
plt.show()
