# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('overallPlayerRecord.csv')
df.head(10)
# Out:
#     pid             name  series_played  matches_played  NOI  total_runs  \
# 0  3243        M S Dhoni             54             222   54        7463
# 1  2191     Abdul Razzaq             34             121   30        2679
# 2  3644       R A Jadeja             30             100   27        1488
# 3  2129  Mohammad Yousuf             40             144   26        5330
# 4  2879     Shoaib Malik             55             188   26        4983
# 5  1169    Javed Miandad             34              93   25        3104
# 6  1794   Inzamam-ul-Haq             45             157   24        4908
# 7  2138  Harbhajan Singh             31             120   23         761
# 8  3600          V Kohli             41             164   23        8628
# 9  2262    Misbah-ul-Haq             32             111   21        3395
#
#    total_ballfaced  total_fours  total_sixes  total_oers  total_maiden_overs  \
# 0             8351          590          168         0.0                   0
# ...
